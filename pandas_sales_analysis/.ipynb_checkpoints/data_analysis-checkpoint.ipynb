# %% [markdown]
# #### Reading files and concatenation of CSVs
#
# in this section, I've used pandas and os packages to import and concat all seprate files to have a unique file for working on it.

# %%
import pandas as pd
import os

# %%
adress_files = "/Users/iman/Documents/Python_notebooks/Python_learning_projects/pandas_sales_analysis/raw_data/"
files = [file for file in os.listdir(adress_files)]

all_months_data = pd.DataFrame()
for file in files: 
    if file != ".DS_Store":
        df = pd.read_csv(adress_files + file)
        all_months_data = pd.concat([all_months_data, df])

# %%
files
# Out:
# ['Sales_December_2019.csv',
#  '.DS_Store',
#  'Sales_April_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_September_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_June_2019.csv']

# %%
all_months_data.to_csv("all_data.csv", index = False)

# %%
all_data = pd.read_csv("all_data.csv")

# %%
all_data
# Out:
#        Order ID                 Product Quantity Ordered Price Each  \
# 0        295665      Macbook Pro Laptop                1       1700
# 1        295666      LG Washing Machine                1      600.0
# 2        295667    USB-C Charging Cable                1      11.95
# 3        295668        27in FHD Monitor                1     149.99
# 4        295669    USB-C Charging Cable                1      11.95
# ...         ...                     ...              ...        ...
# 186845   222905  AAA Batteries (4-pack)                1       2.99
# 186846   222906        27in FHD Monitor                1     149.99
# 186847   222907    USB-C Charging Cable                1      11.95
# 186848   222908    USB-C Charging Cable                1      11.95
# 186849   222909  AAA Batteries (4-pack)                1       2.99
#
#             Order Date                        Purchase Address
# 0       12/30/19 00:01  136 Church St, New York City, NY 10001
# ...

# %% [markdown]
# #### Removing "Or" in first two characters of order date string value

# %%
all_data = all_data[all_data["Order Date"].str[0:2] != "Or"]
all_data
# Out:
#        Order ID                 Product Quantity Ordered Price Each  \
# 0        295665      Macbook Pro Laptop                1       1700
# 1        295666      LG Washing Machine                1      600.0
# 2        295667    USB-C Charging Cable                1      11.95
# 3        295668        27in FHD Monitor                1     149.99
# 4        295669    USB-C Charging Cable                1      11.95
# ...         ...                     ...              ...        ...
# 186845   222905  AAA Batteries (4-pack)                1       2.99
# 186846   222906        27in FHD Monitor                1     149.99
# 186847   222907    USB-C Charging Cable                1      11.95
# 186848   222908    USB-C Charging Cable                1      11.95
# 186849   222909  AAA Batteries (4-pack)                1       2.99
#
#             Order Date                        Purchase Address
# 0       12/30/19 00:01  136 Church St, New York City, NY 10001
# ...

# %% [markdown]
# #### Removing NaN values

# %% [markdown]
# ##### finding all Nan values

# %%
nan_data = all_data[all_data["Month"].isna()]
nan_data
# Out:
#        Order ID Product Quantity Ordered Price Each Order Date  \
# 264         NaN     NaN              NaN        NaN        NaN
# 648         NaN     NaN              NaN        NaN        NaN
# 680         NaN     NaN              NaN        NaN        NaN
# 1385        NaN     NaN              NaN        NaN        NaN
# 1495        NaN     NaN              NaN        NaN        NaN
# ...         ...     ...              ...        ...        ...
# 185795      NaN     NaN              NaN        NaN        NaN
# 185868      NaN     NaN              NaN        NaN        NaN
# 185887      NaN     NaN              NaN        NaN        NaN
# 185960      NaN     NaN              NaN        NaN        NaN
# 186580      NaN     NaN              NaN        NaN        NaN
#
#        Purchase Address Month
# 264                 NaN   NaN
# 648                 NaN   NaN
# 680                 NaN   NaN
# 1385                NaN   NaN
# 1495                NaN   NaN
# ...

# %%
all_data = all_data[all_data["Month"].isna() == False]
all_data
# Out:
#        Order ID                 Product Quantity Ordered Price Each  \
# 0        295665      Macbook Pro Laptop                1       1700
# 1        295666      LG Washing Machine                1      600.0
# 2        295667    USB-C Charging Cable                1      11.95
# 3        295668        27in FHD Monitor                1     149.99
# 4        295669    USB-C Charging Cable                1      11.95
# ...         ...                     ...              ...        ...
# 186845   222905  AAA Batteries (4-pack)                1       2.99
# 186846   222906        27in FHD Monitor                1     149.99
# 186847   222907    USB-C Charging Cable                1      11.95
# 186848   222908    USB-C Charging Cable                1      11.95
# 186849   222909  AAA Batteries (4-pack)                1       2.99
#
#             Order Date                        Purchase Address Month
# 0       12/30/19 00:01  136 Church St, New York City, NY 10001    12
# ...

# %% [markdown]
# #### Q1: what was the best month for sales? and how much sales we had?

# %%
all_data["Month"] = all_data["Order Date"].str[0:2]
all_data
# Out:
# /var/folders/1z/w9ftp6517j94zsn4yj4qy1lc0000gn/T/ipykernel_1516/3244677861.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data["Month"] = all_data["Order Date"].str[0:2]
#        Order ID                 Product Quantity Ordered Price Each  \
# 0        295665      Macbook Pro Laptop                1       1700
# 1        295666      LG Washing Machine                1      600.0
# 2        295667    USB-C Charging Cable                1      11.95
# 3        295668        27in FHD Monitor                1     149.99
# 4        295669    USB-C Charging Cable                1      11.95
# ...         ...                     ...              ...        ...
# 186845   222905  AAA Batteries (4-pack)                1       2.99
# ...

# %%
all_data["Month"] = all_data["Month"].astype("int32")
# Out:
# /var/folders/1z/w9ftp6517j94zsn4yj4qy1lc0000gn/T/ipykernel_1516/4106048089.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data["Month"] = all_data["Month"].astype("int32")

# %% [markdown]
# #### converting numbers to right format

# %%
all_data["Price Each"] = pd.to_numeric(all_data["Price Each"])
all_data["Quantity Ordered"] = pd.to_numeric(all_data["Quantity Ordered"])
# Out:
# /var/folders/1z/w9ftp6517j94zsn4yj4qy1lc0000gn/T/ipykernel_1516/2485450771.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data["Price Each"] = pd.to_numeric(all_data["Price Each"])
# /var/folders/1z/w9ftp6517j94zsn4yj4qy1lc0000gn/T/ipykernel_1516/2485450771.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data["Quantity Ordered"] = pd.to_numeric(all_data["Quantity Ordered"])

# %%
all_data["Sales"] = all_data["Price Each"] * all_data["Quantity Ordered"]
all_data
# Out:
# /var/folders/1z/w9ftp6517j94zsn4yj4qy1lc0000gn/T/ipykernel_1516/1966307576.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data["Sales"] = all_data["Price Each"] * all_data["Quantity Ordered"]
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 0        295665      Macbook Pro Laptop                 1     1700.00
# 1        295666      LG Washing Machine                 1      600.00
# 2        295667    USB-C Charging Cable                 1       11.95
# 3        295668        27in FHD Monitor                 1      149.99
# 4        295669    USB-C Charging Cable                 1       11.95
# ...         ...                     ...               ...         ...
# ...

# %% [markdown]
# ##### Calculating each month sales

# %%
results = all_data.groupby(by = ["Month"]).sum()

# %% [markdown]
# #### Ploting results

# %%
import matplotlib.pyplot as plt

# %%
months = range(1,13)
plt.bar(months, results["Sales"])

plt.show()

# %% [markdown]
# #### How much sales does each city have?

# %%
cc = all_data.copy()
cc
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 0        295665      Macbook Pro Laptop                 1     1700.00
# 1        295666      LG Washing Machine                 1      600.00
# 2        295667    USB-C Charging Cable                 1       11.95
# 3        295668        27in FHD Monitor                 1      149.99
# 4        295669    USB-C Charging Cable                 1       11.95
# ...         ...                     ...               ...         ...
# 186845   222905  AAA Batteries (4-pack)                 1        2.99
# 186846   222906        27in FHD Monitor                 1      149.99
# 186847   222907    USB-C Charging Cable                 1       11.95
# 186848   222908    USB-C Charging Cable                 1       11.95
# 186849   222909  AAA Batteries (4-pack)                 1        2.99
#
#             Order Date                        Purchase Address  Month    Sales
# ...

# %%
t = cc["Purchase Address"].str.split(",", expand = True)
t["city"] = t[1] + t[2].str[0:3]
t["city"].unique()
# Out:
# array([' New York City NY', ' San Francisco CA', ' Atlanta GA',
#        ' Portland OR', ' Dallas TX', ' Los Angeles CA', ' Boston MA',
#        ' Austin TX', ' Portland ME', ' Seattle WA'], dtype=object)

# %%
all_data["City"] = t ["city"]
all_data
# Out:
# /var/folders/1z/w9ftp6517j94zsn4yj4qy1lc0000gn/T/ipykernel_1516/2225842827.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data["City"] = t ["city"]
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 0        295665      Macbook Pro Laptop                 1     1700.00
# 1        295666      LG Washing Machine                 1      600.00
# 2        295667    USB-C Charging Cable                 1       11.95
# 3        295668        27in FHD Monitor                 1      149.99
# 4        295669    USB-C Charging Cable                 1       11.95
# ...         ...                     ...               ...         ...
# 186845   222905  AAA Batteries (4-pack)                 1        2.99
# ...

# %% [markdown]
# ##### simple goup by

# %%
result = all_data.groupby(by=["City"])[["Quantity Ordered", "Sales"]].sum()
result
# Out:
#                   Quantity Ordered       Sales
# City
# Atlanta GA                   16602  2795498.58
# Austin TX                    11153  1819581.75
# Boston MA                    22528  3661642.01
# Dallas TX                    16730  2767975.40
# Los Angeles CA               33289  5452570.80
# New York City NY             27932  4664317.43
# Portland ME                   2750   449758.27
# Portland OR                  11303  1870732.34
# San Francisco CA             50239  8262203.91
# Seattle WA                   16553  2747755.48

# %% [markdown]
# ##### extended group by

# %%
result_2 = all_data.groupby(by=["City"]).agg({
    "Quantity Ordered" : "sum" ,
    "Sales" : "sum", 
    "Price Each" : "mean" })

result_2
# Out:
#                   Quantity Ordered       Sales  Price Each
# City
# Atlanta GA                   16602  2795498.58  186.809233
# Austin TX                    11153  1819581.75  182.723232
# Boston MA                    22528  3661642.01  182.472648
# Dallas TX                    16730  2767975.40  185.737370
# Los Angeles CA               33289  5452570.80  183.125662
# New York City NY             27932  4664317.43  186.339075
# Portland ME                   2750   449758.27  182.154481
# Portland OR                  11303  1870732.34  185.869952
# San Francisco CA             50239  8262203.91  183.570190
# Seattle WA                   16553  2747755.48  185.534619

# %% [markdown]
# #### ploting result

# %%
plt.bar(result_2.index, result_2["Sales"])
plt.xticks(cities, rotation="vertical", size = 10)
plt.show()

# %% [markdown]
# #### Q3: what time should we display advertisements to maximize the liklihood of customers' purchase?

# %%
all_data
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 0        295665      Macbook Pro Laptop                 1     1700.00
# 1        295666      LG Washing Machine                 1      600.00
# 2        295667    USB-C Charging Cable                 1       11.95
# 3        295668        27in FHD Monitor                 1      149.99
# 4        295669    USB-C Charging Cable                 1       11.95
# ...         ...                     ...               ...         ...
# 186845   222905  AAA Batteries (4-pack)                 1        2.99
# 186846   222906        27in FHD Monitor                 1      149.99
# 186847   222907    USB-C Charging Cable                 1       11.95
# 186848   222908    USB-C Charging Cable                 1       11.95
# 186849   222909  AAA Batteries (4-pack)                 1        2.99
#
#             Order Date                        Purchase Address  Month  \
# ...
